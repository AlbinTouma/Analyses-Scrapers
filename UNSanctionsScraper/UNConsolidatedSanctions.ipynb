# %%
import requests
from xml.etree import ElementTree as ET
import json
import pandas as pd
import ast
import numpy as np

# %%
r = requests.get("https://scsanctions.un.org/resources/xml/en/consolidated.xml")

# %%
# Get all the tags in the XML
root = ET.fromstring(r.text)
tags = [children.tag for children in root.find("INDIVIDUALS/INDIVIDUAL")]
mapValues: dict = {}
for item in tags:
    mapValues[item] = None

# %%
individuals: list = root.findall("INDIVIDUALS/INDIVIDUAL")

def parse_xml(element, item):
    for child in element:
        if len(child) == 0:
            if child.tag in item:
                if not isinstance(item[child.tag], list):
                    item[child.tag] = [item[child.tag]]
                item[child.tag].append(child.text)
            else:
                item[child.tag] = child.text
        else:
            if child.tag not in item:
                item[child.tag] = []
            sub_item = {}
            parse_xml(child, sub_item)
            item[child.tag].append(sub_item)

parsed_data = {}
parse_xml(individuals, parsed_data)

# %%
parsed_data
# Out:
# {'INDIVIDUAL': [{'DATAID': '110447',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'MUHAMMAD',
#    'SECOND_NAME': 'TAHER',
#    'THIRD_NAME': 'ANWARI',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.005',
#    'LISTED_ON': '2001-02-23',
#    'NAME_ORIGINAL_SCRIPT': 'Ù\x85Ø\xadÙ\x85Ø¯ Ø·Ø§Ù\x87Ø± Ø£Ù\x86Ù\x88Ø±Ù\x8a',
#    'COMMENTS1': 'Belongs to Andar tribe. Review pursuant to Security Council resolution\n1822 (2008) was concluded on 23 Jul. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Mullah'}],
#    'DESIGNATION': [{'VALUE': ['a) Director of Administrative Affairs under the Taliban\nregime',
#       'Minister of Finance under the Taliban regime']}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-07-09',
#       '2007-09-21',
#       '2011-11-29']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good',
#      'ALIAS_NAME': 'Mohammad Taher Anwari'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Muhammad Tahir Anwari'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Mohammad Tahre Anwari'},
#     {'QUALITY': 'Low', 'ALIAS_NAME': 'Haji Mudir'}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1961'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Zurmat District',
#      'STATE_PROVINCE': 'Paktia Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110554',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'ABDUL LATIF',
#    'SECOND_NAME': 'MANSUR',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.007',
#    'LISTED_ON': '2001-01-31',
#    'NAME_ORIGINAL_SCRIPT': 'Ø¹Ø¨Ø¯ Ø§Ù\x84Ù\x84Ø·Ù\x8aÙ\x81 Ù\x85Ù\x86ØµÙ\x88Ø± ',
#    'COMMENTS1': 'Taliban Shadow Governor for Logar Province as of late 2012. Believed to\nbe in Afghanistan/Pakistan border area. Belongs to Sahak tribe (Ghilzai). Review\npursuant to Security Council resolution 1822 (2008) was concluded on 27 Jul.\n2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Maulavi'}],
#    'DESIGNATION': [{'VALUE': 'Minister of Agriculture under the Taliban regime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-07-18',
#       '2007-09-21',
#       '2012-02-13',
#       '2012-05-18',
#       '2013-04-22']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good',
#      'ALIAS_NAME': 'Abdul Latif Mansoor'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Wali Mohammad'},
#     {'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1968'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Zurmat District',
#      'STATE_PROVINCE': 'Paktia Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110578',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'ABDUL KABIR',
#    'SECOND_NAME': 'MOHAMMAD JAN',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.003',
#    'LISTED_ON': '2001-01-25',
#    'NAME_ORIGINAL_SCRIPT': 'Ø¹Ø¨Ø¯ Ø§Ù\x84Ú©Ø¨Û\x8cØ± Ù\x85Ø\xadÙ\x85Ø¯ Ø¬Ø§Ù\x86',
#    'COMMENTS1': 'Active in terrorist operations in Eastern Afghanistan. Collects money\nfrom drug traffickers. Believed to be in Afghanistan/Pakistan border area. Member of the\nTaliban Supreme Council as at 2009. Family is originally from Neka District, Paktia\nProvince, Afghanistan. Responsible for attack on Afghan parliamentarians in November\n2007 in Baghlan; owns land in central Baghlan Province. Belongs to Zadran tribe. Review\npursuant to Security Council resolution 1822 (2008) was concluded on 23 Jul.\n2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Maulavi'}],
#    'DESIGNATION': [{'VALUE': ['Second Deputy, Economic Affairs, Council of Ministers under the Taliban\nregime',
#       'Governor of Nangarhar Province under the Taliban regime',
#       'Head of Eastern Zone under the Taliban regime']}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2005-12-20',
#       '2007-07-18',
#       '2007-09-21',
#       '2012-02-13',
#       '2012-08-13',
#       '2013-12-31']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good', 'ALIAS_NAME': 'A. Kabir'}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1963'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Pul-e-Khumri or Baghlan Jadid District',
#      'STATE_PROVINCE': 'Baghlan Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110579',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'MOHAMMED',
#    'SECOND_NAME': 'OMAR',
#    'THIRD_NAME': 'GHULAM NABI',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.004',
#    'LISTED_ON': '2000-04-12',
#    'NAME_ORIGINAL_SCRIPT': 'Ù\x85Ø\xadÙ\x85Ø¯ Ø¹Ù\x85Ø± ØºÙ\x84Ø§Ù\x85 Ù\x86Ø¨Û\x8c',
#    'COMMENTS1': "Father's name is Ghulam Nabi, also known as Mullah Musafir. Left eye missing. Brother-in-law of Ahmad Jan Akhundzada Shukoor Akhundzada (TAi.109). Believed to be in Afghanistan/Pakistan border area. Belongs to Hotak tribe. Review pursuant to Security Council resolution 1822 (2008) was concluded on 27 Jul. 2010. Reportedly deceased as of April 2013. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals",
#    'TITLE': [{'VALUE': 'Mullah'}],
#    'DESIGNATION': [{'VALUE': "Leader of the Faithful ('Amir ul-Mumineen'), Afghanistan"}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-09-21',
#       '2011-11-29',
#       '2013-12-31',
#       '2016-09-07']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': None, 'ALIAS_NAME': None},
#     {'QUALITY': None, 'ALIAS_NAME': None, 'DATE_OF_BIRTH': '1960'},
#     {'QUALITY': None, 'ALIAS_NAME': None, 'DATE_OF_BIRTH': '1953'},
#     {'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1966'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Naw Deh village, Deh Rawud District',
#      'STATE_PROVINCE': 'Uruzgan Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110580',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'SAYYED MOHAMMED',
#    'SECOND_NAME': 'HAQQANI',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.006',
#    'LISTED_ON': '2001-01-31',
#    'NAME_ORIGINAL_SCRIPT': 'Ø³Ù\x8aØ¯ Ù\x85Ø\xadÙ\x85Ø¯ Ø\xadÙ\x82Ø§Ù\x86Û\x8c',
#    'COMMENTS1': 'Graduate of the Haqqaniya madrasa in Akora Khattak, Pakistan. Believed to\nhave had close relations with Taliban Leader Mullah Mohammed Omar (TAi.004). Believed to\nbe in Afghanistan/Pakistan border area. Member of Taliban Supreme Council as at June\n2010. Belongs to Barakzai tribe. Review pursuant to Security Council resolution 1822\n(2008) was concluded on 27 Jul. 2010. Photo available for inclusion in the INTERPOL-UN Security Council Special Notice.  Reportedly deceased as of January 2016. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Mullah'}],
#    'DESIGNATION': [{'VALUE': ['Director of Administrative Affairs under the Taliban regime',
#       'Head of Information and Culture in Kandahar Province under the Taliban\nregime']}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2005-12-20',
#       '2007-07-18',
#       '2007-09-21',
#       '2011-11-29',
#       '2016-09-07']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good',
#      'ALIAS_NAME': 'Sayyed Mohammad Haqqani'}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1965'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Chaharbagh village, Arghandab District',
#      'STATE_PROVINCE': 'Kandahar Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110896',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'SHAMS',
#    'SECOND_NAME': 'UR-RAHMAN',
#    'THIRD_NAME': 'ABDUL ZAHIR',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.008',
#    'LISTED_ON': '2001-02-23',
#    'NAME_ORIGINAL_SCRIPT': 'Ø´Ù\x85Ø³ Ø§Ù\x84Ø±Ø\xadÙ\x85Ù\x86 Ø¹Ø¨Ø¯ Ø§Ù\x84Ø¸Ø§Ù\x87Ø±',
#    'COMMENTS1': 'Believed to be in Afghanistan/Pakistan border area. Involved in drug\ntrafficking. Belongs to Ghilzai tribe. Review pursuant to Security Council resolution\n1822 (2008) was concluded on 27 Jul. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': ['Mullah', 'Maulavi']}],
#    'DESIGNATION': [{'VALUE': 'Deputy Minister of Agriculture under the Taliban regime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-09-21',
#       '2010-04-12',
#       '2011-11-29',
#       '2012-05-18']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good', 'ALIAS_NAME': 'Shamsurrahman'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Shams-u-Rahman'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Shamsurrahman Abdurahman'},
#     {'QUALITY': 'Low', 'ALIAS_NAME': 'Shams ur-Rahman Sher Alam'}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'EXACT', 'YEAR': '1969'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Waka Uzbin village, Sarobi District',
#      'STATE_PROVINCE': 'Kabul Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': [{'TYPE_OF_DOCUMENT': 'National Identification Number',
#      'TYPE_OF_DOCUMENT2': 'Afghan national identification card (tazkira) number',
#      'NUMBER': '2132370'},
#     {'TYPE_OF_DOCUMENT': 'National Identification Number',
#      'TYPE_OF_DOCUMENT2': 'Afghan national identification card (tazkira) number',
#      'NUMBER': '812673'}],
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110897',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'MOHAMMAD NAIM',
#    'SECOND_NAME': 'BARICH',
#    'THIRD_NAME': 'KHUDAIDAD',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.013',
#    'LISTED_ON': '2001-02-23',
#    'GENDER': 'Male',
#    'NAME_ORIGINAL_SCRIPT': 'Ù\x85Ø\xadÙ\x85Ø¯ Ù\x86Ø¹Ù\x8aÙ\x85 Ø¨Ø±Ù\x8aØ® Ø®Ø¯Ø§Ù\x8aØ¯Ø§Ø¯',
#    'COMMENTS1': 'Member of the Taliban Military Commission as at mid-2013. Believed to be\nin Afghanistan/Pakistan border area. Belongs to Barich tribe. Review pursuant to\nSecurity Council resolution 1822 (2008) was concluded on 1 Jun. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Mullah'}],
#    'DESIGNATION': [{'VALUE': 'Deputy Minister of Civil Aviation under the Taliban\nregime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-07-09',
#       '2007-09-21',
#       '2012-02-13',
#       '2012-08-13',
#       '2013-04-22',
#       '2013-12-31']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good',
#      'ALIAS_NAME': 'Mullah Naeem Barech'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Mullah Naeem Baraich'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Mullah Naimullah'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Mullah Naim Bareh'},
#     {'QUALITY': 'Good',
#      'ALIAS_NAME': 'Mohammad Naim',
#      'NOTE': 'previously listed as'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Mullah Naim Barich'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Mullah Naim Barech'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Mullah Naim Barech Akhund'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Mullah Naeem Baric'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Naim Berich'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Haji Gul Mohammed Naim Barich'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Gul Mohammad'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Haji Ghul Mohammad'},
#     {'QUALITY': 'Low', 'ALIAS_NAME': 'Spen Zrae'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Gul Mohammad Kamran'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Mawlawi Gul Mohammad'},
#     {'QUALITY': None, 'ALIAS_NAME': None},
#     {'QUALITY': None, 'ALIAS_NAME': None},
#     {'QUALITY': None, 'ALIAS_NAME': None},
#     {'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1975'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Lakhi village, Hazarjuft Area, Garmsir District',
#      'STATE_PROVINCE': 'Helmand Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110899',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'FAZL MOHAMMAD',
#    'SECOND_NAME': 'MAZLOOM',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.023',
#    'LISTED_ON': '2001-02-23',
#    'NAME_ORIGINAL_SCRIPT': 'Ù\x81Ø¶Ù\x84 Ù\x85Ø\xadÙ\x85Ø¯ Ù\x85Ø¸Ù\x84Ù\x88Ù\x85',
#    'COMMENTS1': 'Review pursuant to Security Council resolution 1822 (2008) was concluded on 23 Jul. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Mullah'}],
#    'DESIGNATION': [{'VALUE': 'Deputy Chief of Army Staff of the Taliban regime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-09-21',
#       '2008-10-03',
#       '2013-12-31',
#       '2016-09-07']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good', 'ALIAS_NAME': 'Molah Fazl'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Fazel Mohammad Mazloom'}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': 'Qatar'}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'BETWEEN',
#      'FROM_YEAR': '1963',
#      'TO_YEAR': '1968'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Uruzgan',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110900',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'SAID AHMED',
#    'SECOND_NAME': 'SHAHIDKHEL',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.028',
#    'LISTED_ON': '2001-02-23',
#    'NAME_ORIGINAL_SCRIPT': 'Ø³Ù\x8aØ¯ Ø£Ø\xadÙ\x85Ø¯ Ø´Ù\x87Ù\x8aØ¯ Ø®Ù\x8aÙ\x84',
#    'COMMENTS1': 'In July 2003 he was in custody in Kabul, Afghanistan. Released from\ncustody in 2007. Believed to be in Afghanistan/Pakistan border area. Member of the\nTaliban leadership council as of mid-2013. Belongs to Andar tribe. Review pursuant to\nSecurity Council resolution 1822 (2008) was concluded on 23 Jul. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Maulavi'}],
#    'DESIGNATION': [{'VALUE': 'Deputy Minister of Education under the Taliban regime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2005-12-20',
#       '2007-09-21',
#       '2011-11-29',
#       '2013-12-31']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1975'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Spandeh (Espandi â\x80\x98Olya) village, Andar District',
#      'STATE_PROVINCE': 'Ghazni Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110901',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'MOHAMMAD',
#    'SECOND_NAME': 'AHMADI',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.031',
#    'LISTED_ON': '2001-02-23',
#    'NAME_ORIGINAL_SCRIPT': 'Ù\x85Ø\xadÙ\x85Ø¯ Ø§Ø\xadÙ\x85Ø¯Û\x8c',
#    'COMMENTS1': 'Believed to be in Afghanistan/Pakistan border area. Belongs to Kakar\ntribe. He is a member of the Taliban Supreme Council. Review pursuant to Security\nCouncil resolution 1822 (2008) was concluded on 23 Jul. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': ['Mullah', 'Haji']}],
#    'DESIGNATION': [{'VALUE': ['President of Central Bank (Da Afghanistan Bank) under the Taliban\nregime',
#       'Minister of Finance under the Taliban regime']}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-09-21',
#       '2011-11-29',
#       '2013-12-31']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': None, 'ALIAS_NAME': None},
#     {'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1963'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Daman District',
#      'STATE_PROVINCE': 'Kandahar Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110912',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'ABDUL RAHMAN',
#    'SECOND_NAME': 'ZAHED',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.033',
#    'LISTED_ON': '2001-01-25',
#    'NAME_ORIGINAL_SCRIPT': 'Ø¹Ø¨Ø¯Ø§Ù\x84Ø±Ø\xadÙ\x85Ø§Ù\x86 Ø²Ø§Ù\x87Ø¯',
#    'COMMENTS1': 'Believed to be in Afghanistan/Pakistan border area. Review pursuant to\nSecurity Council resolution 1822 (2008) was concluded on 21 Jul. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Mullah'}],
#    'DESIGNATION': [{'VALUE': 'Deputy Minister of Foreign Affairs under the Taliban\nregime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-07-18',
#       '2007-09-21',
#       '2011-11-29']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good',
#      'ALIAS_NAME': 'Abdul Rehman Zahid'}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1963'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Kharwar District',
#      'STATE_PROVINCE': 'Logar Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110913',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'FAIZ',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.036',
#    'LISTED_ON': '2001-02-23',
#    'NAME_ORIGINAL_SCRIPT': 'Ù\x81Ù\x8aØ¶',
#    'COMMENTS1': 'Review pursuant to Security Council resolution 1822 (2008) was concluded\non 23 Jul. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Maulavi'}],
#    'DESIGNATION': [{'VALUE': 'Head of the Information Department, Ministry of Foreign Affairs under the\nTaliban regime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-07-09',
#       '2007-09-21',
#       '2011-11-29']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1969'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'STATE_PROVINCE': 'Ghazni Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110914',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'ABDUL BAQI',
#    'SECOND_NAME': 'BASIR',
#    'THIRD_NAME': 'AWAL SHAH',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.038',
#    'LISTED_ON': '2001-02-23',
#    'NAME_ORIGINAL_SCRIPT': 'Ø¹Ø¨Ø¯ Ø§Ù\x84Ø¨Ø§Ù\x82Ù\x8a Ø¨ØµÙ\x8aØ± Ø£Ù\x88Ù\x84 Ø´Ø§Ù\x87',
#    'COMMENTS1': 'Believed to be in Afghanistan/Pakistan border area. Taliban member\nresponsible for Nangarhar Province as at 2008. Until 7 Sep. 2007 he was also listed\nunder number TAi.048. Review pursuant to Security Council resolution 1822 (2008) was\nconcluded on 1 Jun. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': ['Maulavi', 'Mullah']}],
#    'DESIGNATION': [{'VALUE': ['Governor of Khost and Paktika provinces under the Taliban\nregime',
#       'Vice-Minister of Information and Culture under the Taliban\nregime',
#       'Consular Department, Ministry of Foreign Affairs under the Taliban\nregime']}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-09-07',
#       '2007-09-21',
#       '2011-11-29',
#       '2012-08-13']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good',
#      'ALIAS_NAME': 'Abdul Baqi',
#      'NOTE': 'previously listed as'},
#     {'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'BETWEEN',
#      'FROM_YEAR': '1960',
#      'TO_YEAR': '1962',
#      'NOTE': 'Approximately '}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Jalalabad City',
#      'STATE_PROVINCE': 'Nangarhar Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110915',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'JALALUDDIN',
#    'SECOND_NAME': 'HAQQANI',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.040',
#    'LISTED_ON': '2001-01-31',
#    'NAME_ORIGINAL_SCRIPT': 'Ø¬Ù\x84Ø§Ù\x84 Ø§Ù\x84Ø¯Ù\x8aÙ\x86 Ø\xadÙ\x82Ø§Ù\x86Ù\x89',
#    'COMMENTS1': 'Father of Sirajuddin Jallaloudine Haqqani (TAi.144), Nasiruddin Haqqani\n(TAi.146) and Badruddin Haqqani (deceased). Brother of Mohammad Ibrahim Omari (TAi.042)\nand Khalil Ahmed Haqqani (TAi.150). He is an active Taliban leader. Believed to be in\nAfghanistan/Pakistan border area. Head of the Taliban Miram Shah Shura as at 2008.\nBelongs to Zadran tribe. Review pursuant to Security Council resolution 1822 (2008) was\nconcluded on 27 Jul. 2010. Reportedly deceased as of September 2018. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Maulavi'}],
#    'DESIGNATION': [{'VALUE': 'Minister of Frontier Affairs under the Taliban regime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-07-18',
#       '2007-09-21',
#       '2007-09-27',
#       '2008-02-01',
#       '2008-07-31',
#       '2008-10-03',
#       '2011-11-29',
#       '2014-02-11',
#       '2019-01-30']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good', 'ALIAS_NAME': 'Jalaluddin Haqani'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Jallalouddin Haqqani'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Jallalouddine Haqani'},
#     {'QUALITY': None, 'ALIAS_NAME': None, 'DATE_OF_BIRTH': '1948'},
#     {'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1942'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Garda Saray area, Waza Zadran District',
#      'STATE_PROVINCE': 'Paktia Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110917',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'DIN MOHAMMAD',
#    'SECOND_NAME': 'HANIF',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.043',
#    'LISTED_ON': '2001-01-25',
#    'NAME_ORIGINAL_SCRIPT': 'Ø¯Û\x8cÙ\x86 Ù\x85Ø\xadÙ\x85Ø¯ Ø\xadÙ\x86Û\x8cÙ\x81',
#    'COMMENTS1': 'Member of Taliban Supreme Council responsible for Takhar and Badakhshan provinces. Believed to be in Afghanistan/Pakistan border area. Review pursuant to Security Council resolution 1822 (2008) was concluded on 27 Jul. 2010. Picture available for inclusion in the INTERPOL-UN Security Council Special Notice. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Qari'}],
#    'DESIGNATION': [{'VALUE': 'a) Minister of Planning under the Taliban regime b) Minister of Higher\nEducation under the Taliban regime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-07-09',
#       '2007-09-21',
#       '2011-11-29',
#       '2012-10-25',
#       '2016-09-07']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good', 'ALIAS_NAME': 'Qari Din Mohammad'},
#     {'QUALITY': 'Good',
#      'ALIAS_NAME': 'Iadena Mohammad',
#      'DATE_OF_BIRTH': '1969-01-01'}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1955'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Shakarlab village, Yaftali Pain District',
#      'STATE_PROVINCE': 'Badakhshan Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': [{'TYPE_OF_DOCUMENT': 'Passport',
#      'NUMBER': 'OA 454044',
#      'COUNTRY_OF_ISSUE': 'Afghanistan'}],
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110941',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'EZATULLAH',
#    'SECOND_NAME': 'HAQQANI',
#    'THIRD_NAME': 'KHAN SAYYID',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.064',
#    'LISTED_ON': '2001-02-23',
#    'NAME_ORIGINAL_SCRIPT': 'Ø¹Ø²Øª Ø§Ù\x84Ù\x84Ù\x87 Ø\xadÙ\x82Ø§Ù\x86Ù\x8a Ø®Ø§Ù\x86 Ø³Ù\x8aØ¯',
#    'COMMENTS1': 'Member of the Taliban Peshawar Shura as of 2008. Believed to be in\nAfghanistan/Pakistan border area. Review pursuant to Security Council resolution 1822\n(2008) was concluded on 1 Jun. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Maulavi'}],
#    'DESIGNATION': [{'VALUE': 'Deputy Minister of Planning under the Taliban regime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-07-18',
#       '2007-09-21',
#       '2007-09-27',
#       '2011-11-29',
#       '2012-05-18']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good',
#      'ALIAS_NAME': 'Ezatullah Haqqani (previously listed as)'}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1957'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Alingar District',
#      'STATE_PROVINCE': 'Laghman Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110942',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'MOHAMMAD ABBAS',
#    'SECOND_NAME': 'AKHUND',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.066',
#    'LISTED_ON': '2001-01-25',
#    'NAME_ORIGINAL_SCRIPT': 'Ù\x85Ø\xadÙ\x85Ø¯ Ø¹Ø¨Ø§Ø³ Ø¢Ø®Ù\x88Ù\x86Ø¯',
#    'COMMENTS1': 'Member of Taliban Supreme Council in charge of the Medical Committee as\nof Jan. 2011. Directly supervises three medical centers caring for wounded Taliban\nfighters as of mid-2013. Believed to be in Afghanistan/Pakistan border area. Belongs to\nBarakzai tribe. Review pursuant to Security Council resolution 1822 (2008) was concluded\non 29 Jul. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Mullah'}],
#    'DESIGNATION': [{'VALUE': ['Mayor of Kandahar under the Taliban regime',
#       'Minister of Public Health under the Taliban regime']}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-09-21',
#       '2011-11-29',
#       '2013-12-31']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1963'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Khas Uruzgan District',
#      'STATE_PROVINCE': 'Uruzgan Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110943',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'RUSTUM',
#    'SECOND_NAME': 'HANAFI',
#    'THIRD_NAME': 'HABIBULLAH',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.069',
#    'LISTED_ON': '2001-01-25',
#    'NAME_ORIGINAL_SCRIPT': 'Ø±Ø³ØªÙ\x85 Ø\xadÙ\x86Ù\x81Û\x8c Ø\xadØ¨Û\x8cØ¨ Ø§Ù\x84Ù\x84Ù\x87',
#    'COMMENTS1': 'Taliban member responsible for Nuristan Province, Afghanistan, as of May\n2007. Belongs to Nuristani tribe. Reportedly deceased in early 2012. Review pursuant to\nSecurity Council resolution 1822 (2008) was concluded on 23 Jul. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Maulavi'}],
#    'DESIGNATION': [{'VALUE': 'Deputy Minister of Public Works under the Taliban regime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-07-18',
#       '2007-09-21',
#       '2011-11-29',
#       '2012-05-18',
#       '2012-08-13']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good', 'ALIAS_NAME': 'Rostam Nuristani'},
#     {'QUALITY': 'Low', 'ALIAS_NAME': 'Hanafi Sahib'}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1963'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Dara Kolum, Do Aab District',
#      'STATE_PROVINCE': 'Nuristan Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110944',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'SAYYED GHIASSOUDDINE',
#    'SECOND_NAME': 'AGHA',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.072',
#    'LISTED_ON': '2001-01-31',
#    'NAME_ORIGINAL_SCRIPT': 'Ø³Ù\x8aØ¯ ØºÛ\x8cØ§Ø« Ø§Ù\x84Ø¯Û\x8cÙ\x86 Ø¢ØºØ§',
#    'COMMENTS1': 'Taliban member responsible for Faryab, Jawzjan, Sari Pul and Balkh\nProvinces, Afghanistan as at June 2010. Involved in drug trafficking. Member of Taliban\nSupreme Council and Taliban Military Council as at December 2009. Believed to be in\nAfghanistan/Pakistan border area. Belongs to Sadat ethnic group. Review pursuant to\nSecurity Council resolution 1822 (2008) was concluded on 27 Jul. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Maulavi'}],
#    'DESIGNATION': [{'VALUE': ['Minister of Haj and Religious Affairs under the Taliban\nregime',
#       'Education Minister under the Taliban regime']}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-07-18',
#       '2007-09-21',
#       '2008-02-01',
#       '2011-11-29']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good', 'ALIAS_NAME': 'Sayed Ghias'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Sayed Ghiasuddin Sayed Ghousuddin'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Sayyed Ghayasudin'}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1961'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Kohistan District',
#      'STATE_PROVINCE': 'Faryab Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110945',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'ABDUL-HAQ',
#    'SECOND_NAME': 'WASSIQ',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.082',
#    'LISTED_ON': '2001-01-31',
#    'NAME_ORIGINAL_SCRIPT': 'Ø¹Ø¨Ø¯ Ø§Ù\x84Ø\xadÙ\x82 Ù\x88Ø«Ù\x8aÙ\x82',
#    'COMMENTS1': 'Review pursuant to Security Council resolution 1822 (2008) was concluded on 27 Jul. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Maulavi'}],
#    'DESIGNATION': [{'VALUE': 'Deputy Minister of Security (Intelligence) under the Taliban\nregime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-09-21',
#       '2008-10-03',
#       '2011-11-29',
#       '2013-12-31',
#       '2014-02-11',
#       '2016-09-07']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good', 'ALIAS_NAME': 'Abdul-Haq Wasseq'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Abdul Haq Wasiq'},
#     {'QUALITY': None, 'ALIAS_NAME': None, 'DATE_OF_BIRTH': '1975'}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': 'Qatar'}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'EXACT', 'YEAR': '1971'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Gharib village, Khogyani District',
#      'STATE_PROVINCE': 'Ghazni Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110947',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'ABDUL JABBAR',
#    'SECOND_NAME': 'OMARI',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.088',
#    'LISTED_ON': '2001-02-23',
#    'NAME_ORIGINAL_SCRIPT': 'Ø¹Ø¨Ø¯Ø§Ù\x84Ø¬Ø¨Ø§Ø± Ø¹Ù\x85Ø±Û\x8c',
#    'COMMENTS1': 'Belongs to Hottak tribe. Review pursuant to Security Council resolution\n1822 (2008) was concluded on 1 Jun. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Maulavi'}],
#    'DESIGNATION': [{'VALUE': 'Governor of Baghlan Province under the Taliban regime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-09-21',
#       '2011-11-29',
#       '2013-04-22']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Low', 'ALIAS_NAME': 'Mullah Jabbar'},
#     {'QUALITY': 'Low', 'ALIAS_NAME': 'Muawin Jabbar'}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1958'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'STATE_PROVINCE': 'Zabul Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110948',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'NURULLAH',
#    'SECOND_NAME': 'NURI',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.089',
#    'LISTED_ON': '2001-01-25',
#    'NAME_ORIGINAL_SCRIPT': 'Ù\x86Ù\x88Ø± Ø§Ù\x84Ù\x84Ù\x87 Ù\x86Ù\x88Ø±Û\x8c',
#    'COMMENTS1': 'Belongs to Tokhi tribe. Review pursuant to Security Council resolution 1822 (2008) was concluded on 29 Jul. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Maulavi'}],
#    'DESIGNATION': [{'VALUE': [' Governor of Balkh Province under the Taliban Regime',
#       ' Head of Northern Zone under the Taliban regime']}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-09-21',
#       '2011-11-29',
#       '2013-12-31',
#       '2016-09-07']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good', 'ALIAS_NAME': 'Norullah Noori'},
#     {'QUALITY': None, 'ALIAS_NAME': None, 'DATE_OF_BIRTH': '1967-01-01'}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': 'Qatar'}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1958'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Shahjoe District',
#      'STATE_PROVINCE': 'Zabul Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110959',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'WALIJAN',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.095',
#    'LISTED_ON': '2001-02-23',
#    'NAME_ORIGINAL_SCRIPT': 'Ù\x88Ù\x84Û\x8c Ø¬Ø§Ù\x86',
#    'COMMENTS1': 'Member of the Taliban Gerd-e-Jangal Shura and Head of the Taliban\nPrisoners and Refugees Committee. Belongs to Ishaqzai tribe. Review pursuant to Security\nCouncil resolution 1822 (2008) was concluded on 23 Jul. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Maulavi'}],
#    'DESIGNATION': [{'VALUE': 'Governor of Jawzjan Province under the Taliban regime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03', '2007-09-21', '2011-11-29']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': None, 'ALIAS_NAME': None},
#     {'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1968'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Quetta', 'COUNTRY': 'Pakistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110960',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'MOHAMMAD HASAN',
#    'SECOND_NAME': 'RAHMANI',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.096',
#    'LISTED_ON': '2001-02-23',
#    'NAME_ORIGINAL_SCRIPT': 'Ù\x85Ø\xadÙ\x85Ø¯ Ø\xadØ³Ù\x86 Ø±Ø\xadÙ\x85Ø§Ù\x86Û\x8c',
#    'COMMENTS1': 'Has a prosthetic right leg. Member of Taliban Supreme Council as of mid-2013, acted as deputy of Mullah Mohammed Omar (TAi.004) in Mar. 2010. Believed to be in Afghanistan/Pakistan border area. Belongs to Achekzai tribe. Review pursuant to Security Council resolution 1822 (2008) was concluded on 23 Jul. 2010. Deceased as of 9 February 2016. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Mullah'}],
#    'DESIGNATION': [{'VALUE': 'Governor of Kandahar Province under the Taliban regime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-09-21',
#       '2011-11-29',
#       '2013-12-31',
#       '2016-09-07']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good',
#      'ALIAS_NAME': 'Gud Mullah Mohammad Hassan'},
#     {'QUALITY': None, 'ALIAS_NAME': None},
#     {'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1963'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Deh Rawud District',
#      'STATE_PROVINCE': 'Uruzgan Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110961',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'ABDUL MANAN',
#    'SECOND_NAME': 'NYAZI',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.097',
#    'LISTED_ON': '2001-01-25',
#    'NAME_ORIGINAL_SCRIPT': 'Ø¹Ø¨Ø¯Ø§Ù\x84Ù\x85Ù\x86Ø§Ù\x86 Ù\x86Û\x8cØ§Ø²Û\x8c',
#    'COMMENTS1': 'Taliban member responsible for Herat, Farah and Nimroz provinces as at\nmid-2013. Member of the Taliban Supreme Council and Quetta Shura. Believed to be in\nAfghanistan/Pakistan border area. Belongs to Achekzai tribe. Involved in transporting\nsuicide bombers to Afghanistan. Review pursuant to Security Council resolution 1822\n(2008) was concluded on 23 Jul. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Mullah'}],
#    'DESIGNATION': [{'VALUE': ['Governor of Kabul Province under the Taliban regime',
#       'Governor of Balk Province under the Taliban regime']}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-07-18',
#       '2007-09-21',
#       '2010-04-12',
#       '2011-11-29',
#       '2012-02-13',
#       '2013-12-31']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good',
#      'ALIAS_NAME': 'Abdul Manan Nayazi'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Abdul Manan Niazi'},
#     {'QUALITY': 'Low', 'ALIAS_NAME': 'Baryaly'},
#     {'QUALITY': 'Low', 'ALIAS_NAME': 'Baryalai'},
#     {'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1968'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Pashtoon Zarghoon District',
#      'STATE_PROVINCE': 'Herat Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110962',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'NAZIR MOHAMMAD',
#    'SECOND_NAME': 'ABDUL BASIR',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.100',
#    'LISTED_ON': '2001-02-23',
#    'NAME_ORIGINAL_SCRIPT': 'Ù\x86Ø¸Ø± Ù\x85Ø\xadÙ\x85Ø¯Ø¹Ø¨Ø¯ Ø§Ù\x84Ø¨ØµÛ\x8cØ±',
#    'COMMENTS1': 'Alternative title: Sar Muallim. Reconciled after the fall of the Taliban\nregime, and assumed duties under the new Government on district level in Kunduz\nProvince. Confirmed assassinated by Taliban on 9 November 2008. Review pursuant to\nSecurity Council resolution 1822 (2008) was concluded on 27 Jul. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Maulavi'}],
#    'DESIGNATION': [{'VALUE': ['Mayor of Kunduz City',
#       'Acting, Governor of Kunduz Province under the Taliban\nregime']}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-09-21',
#       '2012-05-18',
#       '2013-12-31']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good',
#      'ALIAS_NAME': 'Nazar Mohammad',
#      'NOTE': 'previously listed as'}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'EXACT', 'YEAR': '1954'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Malaghi Village, Kunduz District',
#      'STATE_PROVINCE': 'Kunduz Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110963',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'ZIA-UR-RAHMAN',
#    'SECOND_NAME': 'MADANI',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.102',
#    'LISTED_ON': '2001-02-23',
#    'NAME_ORIGINAL_SCRIPT': 'Ø¶Û\x8cØ§ Ø§Ù\x84Ø±Ø\xadÙ\x85Ø§Ù\x86 Ù\x85Ø¯Ù\x86Û\x8c',
#    'COMMENTS1': 'Involved in drug trafficking. Taliban member responsible for military\naffairs in Takhar province, Afghanistan, as of May 2007. Facilitated fund raising in the\nGulf on behalf of the Taliban since 2003. Also facilitated meetings between Taliban\nofficials and wealthy supporters and arranged for more than a dozen individuals to\ntravel to Kabul, Afghanistan, for suicide attacks. Believed to be in the Gulf region.\nReview pursuant to Security Council resolution 1822 (2008) was concluded on 23 Jul.\n2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Maulavi'}],
#    'DESIGNATION': [{'VALUE': 'Governor of Logar Province under the Taliban regime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-07-18',
#       '2007-09-21',
#       '2007-09-27',
#       '2008-02-01',
#       '2012-02-13',
#       '2013-12-31']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good',
#      'ALIAS_NAME': 'Ziaurrahman Madani'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Zaia u Rahman Madani'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Madani Saheb'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Diyaâ\x80\x99 al-Rahman Madani'},
#     {'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1960'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Paliran village, Namakab District',
#      'STATE_PROVINCE': 'Takhar Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110964',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'AHMAD TAHA',
#    'SECOND_NAME': 'KHALID',
#    'THIRD_NAME': 'ABDUL QADIR',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.105',
#    'LISTED_ON': '2001-02-23',
#    'NAME_ORIGINAL_SCRIPT': 'Ø§Ø\xadÙ\x85Ø¯ Ø·Ù\x87 Ø®Ø§Ù\x84Ø¯ Ø¹Ø¨Ø¯ Ø§Ù\x84Ù\x82Ø§Ø¯Ø±',
#    'COMMENTS1': 'Taliban member responsible for Nangarhar Province as at 2011. Believed to\nbe in Afghanistan/Pakistan border area. Belongs to Zadran tribe. Close associate of\nSirajuddin Jallaloudine Haqqani (TAi.144). Review pursuant to Security Council\nresolution 1822 (2008) was concluded on 1 Jun. 2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Maulavi'}],
#    'DESIGNATION': [{'VALUE': 'Governor of Paktia Province under the Taliban regime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03',
#       '2007-09-21',
#       '2008-10-03',
#       '2011-11-29',
#       '2012-08-13']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': None, 'ALIAS_NAME': None},
#     {'QUALITY': None, 'ALIAS_NAME': None},
#     {'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1963'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'STATE_PROVINCE': 'Nangarhar Province',
#      'COUNTRY': 'Afghanistan'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '110965',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'AMINULLAH',
#    'SECOND_NAME': 'AMIN',
#    'THIRD_NAME': 'QUDDUS',
#    'UN_LIST_TYPE': 'Taliban',
#    'REFERENCE_NUMBER': 'TAi.107',
#    'LISTED_ON': '2001-02-23',
#    'NAME_ORIGINAL_SCRIPT': 'Ø§Ù\x85Û\x8cÙ\x86 Ø§Ù\x84Ù\x84Ù\x87 Ø§Ù\x85Û\x8cÙ\x86 Ù\x82Ø¯Ù\x88Ø³',
#    'COMMENTS1': 'Member of Taliban Supreme Council as at 2011. Belongs to Nurzai tribe.\nReview pursuant to Security Council resolution 1822 (2008) was concluded on 27 Jul.\n2010. INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Maulavi'}],
#    'DESIGNATION': [{'VALUE': 'Governor of Saripul Province under the Taliban regime'}],
#    'NATIONALITY': [{'VALUE': 'Afghanistan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2003-09-03', '2007-09-21', '2011-11-29']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good', 'ALIAS_NAME': 'Muhammad Yusuf'},
#     {'QUALITY': 'Good',
#      'ALIAS_NAME': 'Aminullah Amin',
#      'NOTE': 'previously listed as'}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'APPROXIMATELY',
#      'YEAR': '1973'}],
# ...
#    'DESIGNATION': [{'VALUE': 'Previously in charge of Zakat; member of Shura of Al-Shabaab '}],
#    'NATIONALITY': [{'VALUE': 'Somalia'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': None}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Low', 'ALIAS_NAME': 'MOHAMED MIRE'}],
#    'INDIVIDUAL_ADDRESS': [{'STATE_PROVINCE': ' Jilib', 'COUNTRY': 'Somalia'},
#     {'STATE_PROVINCE': 'Qunyo Barrow', 'COUNTRY': 'Somalia'}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'EXACT', 'YEAR': '1962'},
#     {'TYPE_OF_DATE': 'EXACT', 'YEAR': '1960'},
#     {'TYPE_OF_DATE': 'EXACT', 'YEAR': '1955'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'STATE_PROVINCE': 'Kismayo',
#      'COUNTRY': 'Somalia'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '6909267',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'MOHAMED',
#    'SECOND_NAME': 'OMAR ',
#    'THIRD_NAME': 'MOHAMED',
#    'UN_LIST_TYPE': 'Somalia',
#    'REFERENCE_NUMBER': 'SOi.025',
#    'LISTED_ON': '2024-05-21',
#    'COMMENTS1': 'Gender: Male. Listed pursuant to paragraph 26(b) of resolution 2662 (2022): (i) participating in the financing, planning, facilitating, preparing, or perpetrating of acts or activities by, in conjunction with, under the name of, on behalf of, or in support of Al-Shabaab; and (iii) recruiting for, or otherwise supporting acts or activities of Al-Shabaab or any cell, affiliate, splinter group or derivative thereof.',
#    'TITLE': [{'VALUE': 'Wali'}],
#    'DESIGNATION': [{'VALUE': 'Leader (Wali) of the Al-Shabaab group in Diinsor '}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': None}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good',
#      'ALIAS_NAME': 'MAâ\x80\x99D UMUROW'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'MOHAMED OMAR HAJI'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'MOHAMED OMAR MAâ\x80\x99ALIN'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'MOHAMED HAJI OMAR'},
#     {'QUALITY': 'Low', 'ALIAS_NAME': 'MOâ\x80\x99ALIN'}],
#    'INDIVIDUAL_ADDRESS': [{'STREET': 'Diinsor District, Bay Region',
#      'COUNTRY': 'Somalia'},
#     {'STREET': 'Buur Hakaba District, Bay Region', 'COUNTRY': 'Somalia'}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'EXACT', 'YEAR': '1976'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'STREET': 'Taflow Village, Berdaale District, Bay Region',
#      'COUNTRY': 'Somalia'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '6909269',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'ABDEL',
#    'SECOND_NAME': 'RAHMAN',
#    'THIRD_NAME': 'JUMA',
#    'FOURTH_NAME': 'BARKALLA',
#    'UN_LIST_TYPE': 'Sudan',
#    'REFERENCE_NUMBER': 'SDi.005',
#    'LISTED_ON': '2024-11-08',
#    'COMMENTS1': 'Gender: Male.',
#    'DESIGNATION': [{'VALUE': 'Rapid Support Forces (RSF) Major General and West Darfur Commander'}],
#    'NATIONALITY': [{'VALUE': 'Sudan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': None}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'EXACT',
#      'DATE': '1969-01-01'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Bahr Elarab',
#      'STATE_PROVINCE': ' East Darfur',
#      'COUNTRY': 'Sudan'}],
#    'INDIVIDUAL_DOCUMENT': [{'TYPE_OF_DOCUMENT': 'Passport',
#      'NUMBER': 'P07834700 ',
#      'ISSUING_COUNTRY': 'Sudan'},
#     {'TYPE_OF_DOCUMENT': 'National Identification Number',
#      'NUMBER': '21052659309 ',
#      'ISSUING_COUNTRY': 'Sudan'}],
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '6909270',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'OSMAN',
#    'SECOND_NAME': 'MOHAMED ',
#    'THIRD_NAME': 'HAMID ',
#    'FOURTH_NAME': 'MOHAMED',
#    'UN_LIST_TYPE': 'Sudan',
#    'REFERENCE_NUMBER': 'SDi.006',
#    'LISTED_ON': '2024-11-08',
#    'COMMENTS1': 'Gender: Male.',
#    'DESIGNATION': [{'VALUE': 'Rapid Support Forces (RSF) Major General and Head of RSF Operations '}],
#    'NATIONALITY': [{'VALUE': 'Sudan'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': None}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'EXACT',
#      'DATE': '1966-01-01'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Kadiqali',
#      'STATE_PROVINCE': ' South Darfur',
#      'COUNTRY': 'Sudan'}],
#    'INDIVIDUAL_DOCUMENT': [{'TYPE_OF_DOCUMENT': 'National Identification Number',
#      'NUMBER': '11540384888',
#      'ISSUING_COUNTRY': 'Sudan'}],
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '6908654',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'RI',
#    'SECOND_NAME': 'PYONG CHUL',
#    'UN_LIST_TYPE': 'DPRK',
#    'REFERENCE_NUMBER': 'KPi.076',
#    'LISTED_ON': '2017-12-22',
#    'COMMENTS1': 'Gender: male',
#    'DESIGNATION': [{'VALUE': ['Vice Chairman of the Workersâ\x80\x99 Party of Korea (WPK) Central Military Commission',
#       'Former Secretary of the Workerâ\x80\x99s Party and Member of the Political Bureau ',
#       'Former Alternate Member of the Political Bureau of the Workersâ\x80\x99 Party of Korea and First Vice Director of the Munitions Industry Department']}],
#    'NATIONALITY': [{'VALUE': "Democratic People's Republic of Korea"}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2023-06-29', '2024-09-17']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good',
#      'ALIAS_NAME': 'Ri Pyoâ\x80\x99ng-châ\x80\x99oâ\x80\x99l'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Ri Pyong Chol'}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': "Democratic People's Republic of Korea"}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'EXACT', 'YEAR': '1948'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'COUNTRY': None}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '6909274',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'PROPHANE ',
#    'SECOND_NAME': 'VICTOR ',
#    'UN_LIST_TYPE': 'Haiti',
#    'REFERENCE_NUMBER': 'HTi.006',
#    'LISTED_ON': '2024-09-27',
#    'COMMENTS1': 'Gender: Male.',
#    'DESIGNATION': [{'VALUE': 'Former member of the Haitian Parliament, involved in weapons trafficking and using violence to secure political gain.'}],
#    'NATIONALITY': [{'VALUE': 'Haiti'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': None}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': None}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'COUNTRY': None}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '6909275',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'LUCKSON ',
#    'SECOND_NAME': 'ELAN',
#    'UN_LIST_TYPE': 'Haiti',
#    'REFERENCE_NUMBER': 'HTi.007',
#    'LISTED_ON': '2024-09-27',
#    'COMMENTS1': 'Gender: Male.',
#    'DESIGNATION': [{'VALUE': 'Leader of Gran Grif gang.'}],
#    'NATIONALITY': [{'VALUE': 'Haiti'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': None}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': None, 'ALIAS_NAME': None}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'EXACT',
#      'DATE': '1988-01-06'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'COUNTRY': None}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '2894441',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'MUTHANNA',
#    'SECOND_NAME': 'HARITH',
#    'THIRD_NAME': 'SALMAN ',
#    'FOURTH_NAME': 'AL-DARI ',
#    'UN_LIST_TYPE': 'Al-Qaida',
#    'REFERENCE_NUMBER': 'QDi.278',
#    'LISTED_ON': '2010-03-25',
#    'NAME_ORIGINAL_SCRIPT': 'Ù\x85Ø«Ù\x86Ù\x89 Ø\xadØ§Ø±Ø« Ø³Ù\x84Ù\x85Ø§Ù\x86 Ø§Ù\x84Ø¶Ø§Ø±Ù\x8a',
#    'COMMENTS1': 'Motherâ\x80\x99s name: Heba Khamis Dari. Fatherâ\x80\x99s name: Harith bin Salman Al-Dari bin Mahmud al-Shammari Provided operational guidance financial support and other services to or in support of Islamic State in Iraq and the Levant, listed as Al-Qaida in Iraq (AQI) (QDe.115). He is the head of the political department of the Association of Muslim Scholars in Iraq. Involved in oil smuggling. Wanted by the Iraqi security forces. Photo available for inclusion in the INTERPOL-UN Security Council Special Notice. Review pursuant to Security Council resolution 2368 (2017) was concluded on 4 Dec. 2019. Review pursuant to Security Council resolution 2610 (2021) was concluded on 30 October 2023.  INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Doctor'}],
#    'NATIONALITY': [{'VALUE': 'Iraq'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2015-12-10',
#       '2019-12-06',
#       '2023-10-30',
#       '2024-12-02']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good',
#      'ALIAS_NAME': 'Dr. Muthanna Al Dari'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Muthana Harith Al Dari'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Muthanna Harith Sulayman Al-Dari'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Muthanna Harith Sulayman Al-Dhari'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Muthanna Hareth Al-Dhari'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Muthana Haris Al-Dhari'},
#     {'QUALITY': 'Good',
#      'ALIAS_NAME': "Doctor Muthanna Harith Sulayman Al Dari Al-Zawba'"},
#     {'QUALITY': 'Good',
#      'ALIAS_NAME': 'Muthanna Harith Sulayman Al-Dari Al-Zobai'},
#     {'QUALITY': 'Good',
#      'ALIAS_NAME': "Muthanna Harith Sulayman Al-Dari al-Zawba'i"},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Muthanna Hareth al-Dari'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Muthana Haris al-Dari'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Doctor Muthanna al-Dari'},
#     {'QUALITY': 'Good',
#      'ALIAS_NAME': 'Dr. Muthanna Harith al-Dari al-Zowbai'}],
#    'INDIVIDUAL_ADDRESS': [{'CITY': 'Amman', 'COUNTRY': 'Jordan'},
#     {'CITY': 'Khan Dari', 'COUNTRY': 'Iraq', 'NOTE': 'previous'},
#     {'CITY': 'Asas Village',
#      'STATE_PROVINCE': 'Abu Ghurayb',
#      'COUNTRY': 'Iraq',
#      'NOTE': 'previous'},
#     {'COUNTRY': 'Egypt', 'NOTE': 'previous'}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'EXACT',
#      'DATE': '1969-06-16'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'COUNTRY': 'Iraq'}],
#    'INDIVIDUAL_DOCUMENT': [{'TYPE_OF_DOCUMENT': 'National Identification Number',
#      'TYPE_OF_DOCUMENT2': 'Ration card number:',
#      'NUMBER': '1729765'}],
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '6908417',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'MAYSAR ALI',
#    'SECOND_NAME': 'MUSA',
#    'THIRD_NAME': 'ABDALLAH',
#    'FOURTH_NAME': 'AL-JUBURI',
#    'UN_LIST_TYPE': 'Al-Qaida',
#    'REFERENCE_NUMBER': 'QDi.337',
#    'LISTED_ON': '2014-09-23',
#    'COMMENTS1': 'Sharia amir of Al-Nusrah Front for the People of the Levant (QDe.137) as\nof early 2014. Reportedly died in the Syrian Arab Republic on 2 April 2024, Motherâ\x80\x99s name: Subhah Muhammad Sayf. Review pursuant to Security Council resolution 2368 (2017) was concluded on 4 Dec. 2019 Review pursuant to Security Council resolution 2610 (2021) was concluded on 30 October 2023.  INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'TITLE': [{'VALUE': 'Amir'}],
#    'NATIONALITY': [{'VALUE': 'Iraq'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2019-12-06', '2023-10-30', '2024-12-02']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good',
#      'ALIAS_NAME': 'Muyassir al-Jiburi'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Muyassir Harara'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Muyassir al-Shammari'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Muhammad Khalid Hassan'},
#     {'QUALITY': 'Low', 'ALIAS_NAME': 'Al-Shammari'},
#     {'QUALITY': 'Low', 'ALIAS_NAME': "Mus'ab al-Qahtani"},
#     {'QUALITY': 'Low', 'ALIAS_NAME': 'Abu Maria al-Qatani'},
#     {'QUALITY': 'Low',
#      'ALIAS_NAME': 'ABU UMAR',
#      'NOTE': 'Responsable de la charia du Front el-Nosra pour le peuple du Levant (QDe.137) au dÃ©but de 2014. Serait dÃ©cÃ©dÃ© le 2 avril 2024 en RÃ©publique arabe syrienne. Nom de la mÃ¨re : Subhah Muhammad Sayf. Lâ\x80\x99examen de lâ\x80\x99inscription en application de la rÃ©solution 2368 (2017) sâ\x80\x99est achevÃ© le 4 dÃ©c. 2019. La rÃ©vision prÃ©vue par la rÃ©solution 2610 (2021) du Conseil de sÃ©curitÃ© a Ã©tÃ© achevÃ©e le 30 octobre 2023. '}],
#    'INDIVIDUAL_ADDRESS': [{'COUNTRY': None}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'EXACT',
#      'DATE': '1976-06-01'},
#     {'TYPE_OF_DATE': 'EXACT', 'YEAR': '1976'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Al-Shura',
#      'STATE_PROVINCE': 'Mosul',
#      'COUNTRY': 'Iraq'},
#     {'STATE_PROVINCE': 'Hararah, Ninawa Province', 'COUNTRY': 'Iraq'}],
#    'INDIVIDUAL_DOCUMENT': None,
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None},
#   {'DATAID': '6908658',
#    'VERSIONNUM': '1',
#    'FIRST_NAME': 'SALIM',
#    'SECOND_NAME': 'MUSTAFA',
#    'THIRD_NAME': 'MUHAMMAD',
#    'FOURTH_NAME': 'AL-MANSUR',
#    'UN_LIST_TYPE': 'Al-Qaida',
#    'REFERENCE_NUMBER': 'QDi.411',
#    'LISTED_ON': '2018-03-06',
#    'NAME_ORIGINAL_SCRIPT': 'Ø³Ø§Ù\x84Ù\x85 Ù\x85ØµØ·Ù\x81Ù\x89 Ù\x85Ø\xadÙ\x85Ø¯ Ø§Ù\x84 Ù\x85Ù\x86ØµÙ\x88Ø±',
#    'COMMENTS1': ': Finance â\x80\x9cemirâ\x80\x9d for Islamic State in Iraq and the Levant, listed as Al-Qaida in Iraq (QDe.115). Motherâ\x80\x99s name: Khadijah Mustafa Salih , Held in detention by the Iraqi intelligence service since 2019 and has been sentenced to death, Physical description: hair colour: black; eye colour: honey; height: 170 cm. Speaks Arabic. Review pursuant to Security Council resolution 2610 (2021) was concluded on 30 October 2023.  INTERPOL-UN Security Council Special Notice web link:https://www.interpol.int/en/How-we-work/Notices/View-UN-Notices-Individuals',
#    'NATIONALITY': [{'VALUE': 'Iraq'}],
#    'LIST_TYPE': [{'VALUE': 'UN List'}],
#    'LAST_DAY_UPDATED': [{'VALUE': ['2023-10-30', '2024-12-02']}],
#    'INDIVIDUAL_ALIAS': [{'QUALITY': 'Good',
#      'ALIAS_NAME': 'Salim Mustafa Muhammad Mansur Al-Ifri'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Saleem Al-Ifri'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Salim Mansur Mustafa'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Salim Mansur'},
#     {'QUALITY': 'Good', 'ALIAS_NAME': 'Hajji Salim Al-Shaklar'}],
#    'INDIVIDUAL_ADDRESS': [{'STREET': '17 Tamoz',
#      'CITY': 'Mosul',
#      'COUNTRY': 'Iraq',
#      'NOTE': 'previous address'},
#     {'STREET': 'Tel Afar â\x80\x93 Al-Saad',
#      'CITY': 'Mosul',
#      'COUNTRY': 'Iraq',
#      'NOTE': 'previous address'}],
#    'INDIVIDUAL_DATE_OF_BIRTH': [{'TYPE_OF_DATE': 'EXACT',
#      'DATE': '1962-02-20'},
#     {'TYPE_OF_DATE': 'EXACT', 'YEAR': '1959'}],
#    'INDIVIDUAL_PLACE_OF_BIRTH': [{'CITY': 'Baghdad', 'COUNTRY': 'Iraq'},
#     {'CITY': 'Tel Afar',
#      'STATE_PROVINCE': ' Nineveh Province',
#      'COUNTRY': 'Iraq'}],
#    'INDIVIDUAL_DOCUMENT': [{'TYPE_OF_DOCUMENT': 'Passport',
#      'NUMBER': 'A6489694',
#      'ISSUING_COUNTRY': 'Iraq',
#      'DATE_OF_ISSUE': '2013-09-02',
#      'NOTE': 'expires on 31 Aug. 2021; name in Arabic script: Ø³Ø§Ù\x84Ù\x85 Ù\x85ØµØ·Ù\x81Ù\x89 Ù\x85Ø\xadÙ\x85Ø¯ Ø§Ù\x84\nÙ\x85Ù\x86ØµÙ\x88Ø±'},
#     {'TYPE_OF_DOCUMENT': 'National Identification Number',
#      'TYPE_OF_DOCUMENT2': 'national identification card',
#      'NUMBER': '00813602',
#      'ISSUING_COUNTRY': 'Iraq',
#      'DATE_OF_ISSUE': '2011-09-18',
#      'NOTE': 'name in Arabic script: Ø³Ø§Ù\x84Ù\x85 Ù\x85ØµØ·Ù\x81Ù\x89 Ù\x85Ø\xadÙ\x85Ø¯ Ø§Ù\x84 Ù\x85Ù\x86ØµÙ\x88Ø±'},
#     {'TYPE_OF_DOCUMENT': 'National Identification Number',
#      'TYPE_OF_DOCUMENT2': 'Certificate of Iraqi Nationality',
#      'NUMBER': '300397',
#      'ISSUING_COUNTRY': 'Iraq',
#      'DATE_OF_ISSUE': '2013-06-25',
#      'NOTE': 'name in Arabic script: Ø³Ø§Ù\x84Ù\x85 Ù\x85ØµØ·Ù\x81Ù\x89 Ù\x85Ø\xadÙ\x85Ø¯'}],
#    'SORT_KEY': None,
#    'SORT_KEY_LAST_MOD': None}]}

# %%
df = pd.DataFrame(parsed_data['INDIVIDUAL'])

# %%
def first_name(df):
    name = df['FIRST_NAME'].fillna('') + ' ' + df['SECOND_NAME'].fillna('') + ' ' + df['THIRD_NAME'].fillna('') + ' ' + df['FOURTH_NAME'].fillna('')
    return name.apply(lambda x: x.strip())

df['FULL_NAME'] = first_name(df)

# %%
def parse_dates(row):
    year  = []
    death = []
    if len(row) == 0:
        pass
    for item in row:
        if 'YEAR' in item:
            year.append(item['YEAR'])
        if 'FROM_YEAR' in item:
            year.append(item['FROM_YEAR'])
        if 'TO_YEAR' in item:
            death.append(item['TO_YEAR'])
    return year, death

            
            

df['INDIVIDUAL_DATE_OF_BIRTH'] = [ [] if x is np.NaN else x for x in df['INDIVIDUAL_DATE_OF_BIRTH'] ]
df['birth_date'], df['death_date'] = zip(*df['INDIVIDUAL_DATE_OF_BIRTH'].copy().apply(lambda x: parse_dates(x)))
#df['birth_date'] = ['' if x == [] else x[0] for x in df['birth_date'].copy()]
#df['death_date'] = ['' if x == [] else x[0] for x in df['death_date'].copy()]
#dict_keys(['TYPE_OF_DATE', 'FROM_YEAR', 'TO_YEAR'])
#df['INDIVIDUAL_DATE_OF_BIRTH'].apply(lambda x: [print(item.keys()) for item in x])

# %%
def parse_place_birth(row):
    city = []
    state = []
    country = []
    for item in row:
        if 'CITY' in item:
            city.append(item['CITY'])
        if 'STATE_PROVINCE' in item:
            state.append(item['STATE_PROVINCE'])
        if 'COUNTRY' in item:
            country.append(item['COUNTRY'])

    return city, state, country

df['city_birth'], df['state_birth'], df['country_birth'] = zip(*df['INDIVIDUAL_PLACE_OF_BIRTH'].apply(lambda x: parse_place_birth(x)))

# %% [markdown]
# url = "https://api.pocketbase.io/v1/databases/<your-database-id>/collections/<your-collection>"
# headers = {"Content-Type": "application/json", "Authorization": "<your-api-key>"}
# data = {"name": "Sameer", "age": 23}
# response = requests.post(url, headers=headers, data=json.dumps(data))
# if response.status_code == 201:
#     print("Data stored successfully!")
# else:
#     print("Failed to store data")
