# %%
import requests
from xml.etree import ElementTree as ET
import json
import pandas as pd
import ast
import numpy as np

# %%
r = requests.get("https://scsanctions.un.org/resources/xml/en/consolidated.xml")

# %%
# Get all the tags in the XML
root = ET.fromstring(r.text)
tags = [children.tag for children in root.find("INDIVIDUALS/INDIVIDUAL")]
mapValues: dict = {}
for item in tags:
    mapValues[item] = None

# %%
individuals: list = root.findall("INDIVIDUALS/INDIVIDUAL")

def parse_xml(element, item):
    for child in element:
        if len(child) == 0:
            if child.tag in item:
                if not isinstance(item[child.tag], list):
                    item[child.tag] = [item[child.tag]]
                item[child.tag].append(child.text)
            else:
                item[child.tag] = child.text
        else:
            if child.tag not in item:
                item[child.tag] = []
            sub_item = {}
            parse_xml(child, sub_item)
            item[child.tag].append(sub_item)

parsed_data = {}
parse_xml(individuals, parsed_data)

# %%
df = pd.DataFrame(parsed_data['INDIVIDUAL'])

# %%
def first_name(df):
    name = df['FIRST_NAME'].fillna('') + ' ' + df['SECOND_NAME'].fillna('') + ' ' + df['THIRD_NAME'].fillna('') + ' ' + df['FOURTH_NAME'].fillna('')
    return name.apply(lambda x: x.strip())

df['FULL_NAME'] = first_name(df)

# %%
def parse_dates(row):
    year  = []
    death = []
    if len(row) == 0:
        pass
    for item in row:
        if 'YEAR' in item:
            year.append(item['YEAR'])
        if 'FROM_YEAR' in item:
            year.append(item['FROM_YEAR'])
        if 'TO_YEAR' in item:
            death.append(item['TO_YEAR'])

    return year, death

            
            

df['INDIVIDUAL_DATE_OF_BIRTH'] = [ [] if x is np.NaN else x for x in df['INDIVIDUAL_DATE_OF_BIRTH'] ]
df['birth_date'], df['death_date'] = zip(*df['INDIVIDUAL_DATE_OF_BIRTH'].copy().apply(lambda x: parse_dates(x)))
df
#df[df['INDIVIDUAL_DATE_OF_BIRTH'] == '']
#dict_keys(['TYPE_OF_DATE', 'FROM_YEAR', 'TO_YEAR'])
#df['INDIVIDUAL_DATE_OF_BIRTH'].apply(lambda x: [print(item.keys()) for item in x])
# Out:
#       DATAID VERSIONNUM       FIRST_NAME   SECOND_NAME   THIRD_NAME  \
# 0     110447          1         MUHAMMAD         TAHER       ANWARI
# 1     110554          1      ABDUL LATIF        MANSUR          NaN
# 2     110578          1      ABDUL KABIR  MOHAMMAD JAN          NaN
# 3     110579          1         MOHAMMED          OMAR  GHULAM NABI
# 4     110580          1  SAYYED MOHAMMED       HAQQANI          NaN
# ..       ...        ...              ...           ...          ...
# 681  6909274          1        PROPHANE        VICTOR           NaN
# 682  6909275          1         LUCKSON           ELAN          NaN
# 683  2894441          1         MUTHANNA        HARITH      SALMAN
# 684  6908417          1       MAYSAR ALI          MUSA     ABDALLAH
# 685  6908658          1            SALIM       MUSTAFA     MUHAMMAD
#
#     UN_LIST_TYPE REFERENCE_NUMBER   LISTED_ON  \
# 0        Taliban          TAi.005  2001-02-23
# 1        Taliban          TAi.007  2001-01-31
# 2        Taliban          TAi.003  2001-01-25
# 3        Taliban          TAi.004  2000-04-12
# 4        Taliban          TAi.006  2001-01-31
# ..           ...              ...         ...
# 681        Haiti          HTi.006  2024-09-27
# 682        Haiti          HTi.007  2024-09-27
# 683     Al-Qaida          QDi.278  2010-03-25
# 684     Al-Qaida          QDi.337  2014-09-23
# 685     Al-Qaida          QDi.411  2018-03-06
#
#                              NAME_ORIGINAL_SCRIPT  \
# 0                    Ù
# Ø­Ù
# Ø¯ Ø·Ø§ÙØ± Ø£ÙÙØ±Ù
# 1                 Ø¹Ø¨Ø¯ Ø§ÙÙØ·ÙÙ Ù
# ÙØµÙØ±
# 2             Ø¹Ø¨Ø¯ Ø§ÙÚ©Ø¨ÛØ± Ù
# Ø­Ù
# Ø¯ Ø¬Ø§Ù
# 3                 Ù
# Ø­Ù
# Ø¯ Ø¹Ù
# Ø± ØºÙØ§Ù
#  ÙØ¨Û
# 4                      Ø³ÙØ¯ Ù
# Ø­Ù
# Ø¯ Ø­ÙØ§ÙÛ
# ..                                            ...
# 681                                           NaN
# 682                                           NaN
# 683     Ù
# Ø«ÙÙ Ø­Ø§Ø±Ø« Ø³ÙÙ
# Ø§Ù Ø§ÙØ¶Ø§Ø±Ù
# 684                                           NaN
# 685  Ø³Ø§ÙÙ
#  Ù
# ØµØ·ÙÙ Ù
# Ø­Ù
# Ø¯ Ø§Ù Ù
# ÙØµÙØ±
#
#                                              COMMENTS1  ...  \
# 0    Belongs to Andar tribe. Review pursuant to Sec...  ...
# 1    Taliban Shadow Governor for Logar Province as ...  ...
# 2    Active in terrorist operations in Eastern Afgh...  ...
# 3    Father's name is Ghulam Nabi, also known as Mu...  ...
# 4    Graduate of the Haqqaniya madrasa in Akora Kha...  ...
# ..                                                 ...  ...
# 681                                      Gender: Male.  ...
# 682                                      Gender: Male.  ...
# 683  Motherâs name: Heba Khamis Dari. Fatherâs ...  ...
# 684  Sharia amir of Al-Nusrah Front for the People ...  ...
# 685  : Finance âemirâ for Islamic State in Iraq...  ...
#
#                              INDIVIDUAL_PLACE_OF_BIRTH  \
# 0    [{'CITY': 'Zurmat District', 'STATE_PROVINCE':...
# 1    [{'CITY': 'Zurmat District', 'STATE_PROVINCE':...
# 2    [{'CITY': 'Pul-e-Khumri or Baghlan Jadid Distr...
# 3    [{'CITY': 'Naw Deh village, Deh Rawud District...
# 4    [{'CITY': 'Chaharbagh village, Arghandab Distr...
# ..                                                 ...
# 681                                [{'COUNTRY': None}]
# 682                                [{'COUNTRY': None}]
# 683                              [{'COUNTRY': 'Iraq'}]
# 684  [{'CITY': 'Al-Shura', 'STATE_PROVINCE': 'Mosul...
# 685  [{'CITY': 'Baghdad', 'COUNTRY': 'Iraq'}, {'CIT...
#
#                                    INDIVIDUAL_DOCUMENT SORT_KEY  \
# 0                                                 None     None
# 1                                                 None     None
# 2                                                 None     None
# 3                                                 None     None
# 4                                                 None     None
# ..                                                 ...      ...
# 681                                               None     None
# 682                                               None     None
# 683  [{'TYPE_OF_DOCUMENT': 'National Identification...     None
# 684                                               None     None
# 685  [{'TYPE_OF_DOCUMENT': 'Passport', 'NUMBER': 'A...     None
#
#     SORT_KEY_LAST_MOD GENDER FOURTH_NAME                           FULL_NAME  \
# 0                None    NaN         NaN               MUHAMMAD TAHER ANWARI
# 1                None    NaN         NaN                  ABDUL LATIF MANSUR
# 2                None    NaN         NaN            ABDUL KABIR MOHAMMAD JAN
# 3                None    NaN         NaN           MOHAMMED OMAR GHULAM NABI
# 4                None    NaN         NaN             SAYYED MOHAMMED HAQQANI
# ..                ...    ...         ...                                 ...
# 681              None    NaN         NaN                    PROPHANE  VICTOR
# 682              None    NaN         NaN                       LUCKSON  ELAN
# 683              None    NaN    AL-DARI      MUTHANNA HARITH SALMAN  AL-DARI
# 684              None    NaN   AL-JUBURI  MAYSAR ALI MUSA ABDALLAH AL-JUBURI
# 685              None    NaN   AL-MANSUR    SALIM MUSTAFA MUHAMMAD AL-MANSUR
#
#     birth_date death death_date
# 0       [1961]    []         []
# 1       [1968]    []         []
# 2       [1963]    []         []
# 3       [1966]    []         []
# 4       [1965]    []         []
# ..         ...   ...        ...
# 681         []    []         []
# 682         []    []         []
# 683         []    []         []
# 684     [1976]    []         []
# 685     [1959]    []         []
#
# [686 rows x 28 columns]

# %% [markdown]
# url = "https://api.pocketbase.io/v1/databases/<your-database-id>/collections/<your-collection>"
# headers = {"Content-Type": "application/json", "Authorization": "<your-api-key>"}
# data = {"name": "Sameer", "age": 23}
# response = requests.post(url, headers=headers, data=json.dumps(data))
# if response.status_code == 201:
#     print("Data stored successfully!")
# else:
#     print("Failed to store data")
